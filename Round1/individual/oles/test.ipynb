# %%
import sys
import os
import numpy as np 

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../..')))

from utilities.log_processor import LogProcessor

processor = LogProcessor('../../logs/nothing_bot@07_04_2025_1300.log')
processor.read_log()

kelp_trade_history = processor.trade_history[processor.trade_history['symbol'] == "KELP"]
resin_trade_history = processor.trade_history[processor.trade_history['symbol'] == "RAINFOREST_RESIN"]
squid_trade_history = processor.trade_history[processor.trade_history['symbol'] == "SQUID_INK"]

# %%
squid_trade_history
# Out:
#      timestamp buyer seller     symbol   currency  price  quantity
# 4          200               SQUID_INK  SEASHELLS   1835         1
# 6          300               SQUID_INK  SEASHELLS   1836         1
# 8          500               SQUID_INK  SEASHELLS   1836         1
# 10         600               SQUID_INK  SEASHELLS   1834         5
# 12         700               SQUID_INK  SEASHELLS   1834         1
# ..         ...   ...    ...        ...        ...    ...       ...
# 826      98200               SQUID_INK  SEASHELLS   1814         6
# 833      99200               SQUID_INK  SEASHELLS   1811         2
# 838      99600               SQUID_INK  SEASHELLS   1818        12
# 841      99700               SQUID_INK  SEASHELLS   1813         2
# 843      99900               SQUID_INK  SEASHELLS   1816         1
#
# [280 rows x 7 columns]
